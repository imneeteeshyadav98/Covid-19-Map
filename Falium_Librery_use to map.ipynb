# %%
import folium

# %%
dataset=pd.read_csv("Covid-19.csv")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 6 columns):
# State           31 non-null object
# Active          31 non-null int64
# Latitude        31 non-null float64
# Longitude       31 non-null float64
# Hotspot Area    31 non-null int64
# Death           31 non-null int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.6+ KB

# %%
dataset.columns
# Out:
# Index(['State', 'Active', 'Latitude', 'Longitude', 'Hotspot Area', 'Death'], dtype='object')

# %%
dataset.head()
# Out:
#            State  Active   Latitude  Longitude  Hotspot Area  Death
# 0    Jamu Kasmir     454  33.882973  74.278867             6      5
# 1          Delhi    2514  28.647278  76.812383             9     53
# 2  Uttar Prdaesh    1778  28.207609  79.826660            11     26
# 3          Bihar     228  25.901938  84.678240             1      2
# 4           Asam      36  26.244156  92.537842             0      1

# %%
place=dataset[['Latitude','Longitude']]

# %%
type(place)
# Out:
# pandas.core.frame.DataFrame

# %%
place=place.values.tolist()

# %%
type(place)
# Out:
# list

# %%
cmap=folium.Map(location=[20.593684,78.96288],zoom_start=4)

# %%
def lw(i,color):
    folium.Marker(
            location=point, 
            popup="State Name:"+dataset['State'][i]+"\n"+"Active Case:"+str(dataset['Active'][i])+"\n"
            +"Death:"+str(dataset['Death'][i])+"\n"+"Hotspot Area:"+str(dataset['Hotspot Area'][i]),
            icon=folium.Icon(color=color, icon='tint', icon_color='white' )
        ).add_to(cmap)

# %%
#circle marker
def cir(i,color):
    folium.CircleMarker(
            location=point, 
            popup="State Name:"+dataset['State'][i]+"\n"+"Active Case:"+str(dataset['Active'][i])+"\n"
            +"Death:"+str(dataset['Death'][i]),
            icon=folium.Icon(color=color, icon='tint', icon_color='white' )
        ).add_to(cmap)

# %%
i=0
for point in place:
    if dataset['Active'][i]>=1000:
        lw(i,'red')
    elif  dataset['Hotspot Area'][i]>=3:
        cir(i,'orange')
    else:
        lw(i,'green')
    i+=1

# %%
cmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
